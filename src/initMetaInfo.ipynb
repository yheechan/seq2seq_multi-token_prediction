# %%
import recorder

# %%
# version2
proj_list = [
    'boringssl', 'c-ares',
    'freetype2', 'guetzli',
    'harfbuzz', 'lcms',
    'libarchive', 'libpng',
    'libssh', 'libxml2',
    'pcre2', 'proj4',
    're2', 'sqlite3',
    'vorbis', 'woff2',
    'wpantund'
]

# version3
proj_list = [
    'boringssl', 'c-ares',
    'freetype2', 'guetzli',
    'harfbuzz', 'lcms',
    'libpng', 'libssh',
    'libxml2', 'pcre2',
    'proj4', 're2',
    'sqlite3', 'vorbis',
    'woff2', 'wpantund'
]

version = 'version4'
proj_list = [
    'total_aspell', 'total_boringssl', 'total_c-ares', 'total_exiv2',
    'total_freetype2', 'total_grok', 'total_guetzli', 'total_harfbuzz',
    'total_lcms', 'total_libarchive', 'total_libexif', 'total_libhtp',
    'total_libpng', 'total_libsndfile', 'total_libssh', 'total_libxml2',
    'total_ndpi', 'total_openthread', 'total_pcre2', 'total_proj4',
    'total_re2', 'total_sqlite3', 'total_usrsctp', 'total_vorbis',
    'total_woff2', 'total_wpantund', 'total_yara', 'total_zstd'
]

# %%
recorder.recordInfo(proj_list, version)
# Out:
# checking project "total_aspell"
# added choice "123"
# added source code prefix token to list of tokens"0"
# added source code prefix token to list of tokens"65"
# added source code prefix token to list of tokens"123"
# added source code prefix token to list of tokens"54"
# added source code prefix token to list of tokens"99"
# added source code prefix token to list of tokens"97"
# added source code prefix token to list of tokens"37"
# added source code prefix token to list of tokens"125"
# added source code prefix token to list of tokens"91"
# added source code prefix token to list of tokens"21"
# added source code prefix token to list of tokens"118"
# added source code prefix token to list of tokens"55"
# added source code prefix token to list of tokens"85"
# added source code prefix token to list of tokens"23"
# added source code prefix token to list of tokens"5"
# added source code prefix token to list of tokens"8"
# added source code postfix token to list of tokens"57"
# added source code postfix token to list of tokens"101"
# added source code postfix token to list of tokens"84"
# added source code postfix token to list of tokens"52"
# added choice "97"
# added source code postfix token to list of tokens"127"
# added source code postfix token to list of tokens"22"
# added source code postfix token to list of tokens"20"
# added source code postfix token to list of tokens"83"
# added source code postfix token to list of tokens"48"
# added source code postfix token to list of tokens"12"
# added source code postfix token to list of tokens"4"
# added choice "125"
# added source code postfix token to list of tokens"64"
# added source code postfix token to list of tokens"105"
# added source code postfix token to list of tokens"49"
# added source code postfix token to list of tokens"40"
# added choice "5"
# added choice "105"
# added source code postfix token to list of tokens"29"
# added source code postfix token to list of tokens"90"
# added choice "29"
# added source code postfix token to list of tokens"121"
# added source code postfix token to list of tokens"18"
# added source code postfix token to list of tokens"24"
# added source code postfix token to list of tokens"107"
# added source code postfix token to list of tokens"43"
# added source code postfix token to list of tokens"45"
# added source code postfix token to list of tokens"6"
# added source code postfix token to list of tokens"38"
# added choice "43"
# added source code postfix token to list of tokens"53"
# added source code postfix token to list of tokens"42"
# added source code postfix token to list of tokens"108"
# added choice "108"
# added source code prefix token to list of tokens"72"
# added source code prefix token to list of tokens"69"
# added choice "37"
# added source code prefix token to list of tokens"62"
# added source code postfix token to list of tokens"66"
# added choice "66"
# added source code postfix token to list of tokens"79"
# added choice "79"
# added choice "55"
# added choice "40"
# added source code postfix token to list of tokens"34"
# added choice "38"
# added source code postfix token to list of tokens"76"
# added source code postfix token to list of tokens"39"
# added choice "39"
# added source code postfix token to list of tokens"30"
# added source code prefix token to list of tokens"78"
# added source code prefix token to list of tokens"126"
# added choice "78"
# added choice "126"
# added choice "127"
# added source code postfix token to list of tokens"77"
# added source code postfix token to list of tokens"110"
# added source code prefix token to list of tokens"47"
# added source code postfix token to list of tokens"86"
# added source code postfix token to list of tokens"56"
# added source code postfix token to list of tokens"132"
# added source code postfix token to list of tokens"115"
# added choice "56"
# added source code postfix token to list of tokens"13"
# added source code postfix token to list of tokens"82"
# added source code postfix token to list of tokens"102"
# added source code postfix token to list of tokens"103"
# added source code postfix token to list of tokens"16"
# added choice "8"
# added source code postfix token to list of tokens"28"
# added choice "62"
# added source code postfix token to list of tokens"26"
# added source code postfix token to list of tokens"80"
# added source code postfix token to list of tokens"19"
# added source code postfix token to list of tokens"117"
# added source code prefix token to list of tokens"59"
# added choice "59"
# added source code prefix token to list of tokens"94"
# added source code prefix token to list of tokens"95"
# added source code prefix token to list of tokens"92"
# added source code postfix token to list of tokens"104"
# added source code prefix token to list of tokens"112"
# added choice "77"
# added choice "94"
# added source code postfix token to list of tokens"58"
# added source code postfix token to list of tokens"88"
# added source code postfix token to list of tokens"75"
# added source code postfix token to list of tokens"60"
# added source code postfix token to list of tokens"74"
# added source code postfix token to list of tokens"50"
# added source code postfix token to list of tokens"61"
# added choice "64"
# added choice "69"
# added source code postfix token to list of tokens"31"
# added source code postfix token to list of tokens"63"
# added choice "57"
# added choice "54"
# added source code postfix token to list of tokens"98"
# added source code postfix token to list of tokens"96"
# added source code prefix token to list of tokens"116"
# added source code postfix token to list of tokens"35"
# added choice "63"
# added source code postfix token to list of tokens"70"
# added source code postfix token to list of tokens"93"
# added choice "21"
# added choice "107"
# added source code postfix token to list of tokens"7"
# added source code postfix token to list of tokens"32"
# added source code postfix token to list of tokens"114"
# added source code prefix token to list of tokens"111"
# added choice "111"
# added source code postfix token to list of tokens"46"
# added source code postfix token to list of tokens"81"
# added choice "50"
# added source code postfix token to list of tokens"135"
# added choice "135"
# added source code prefix token to list of tokens"119"
# added source code prefix token to list of tokens"120"
# added source code postfix token to list of tokens"87"
# checking project "total_boringssl"
# added source code postfix token to list of tokens"51"
# added source code prefix token to list of tokens"14"
# added source code postfix token to list of tokens"15"
# added source code prefix token to list of tokens"33"
# added source code postfix token to list of tokens"10"
# added source code prefix token to list of tokens"71"
# added source code postfix token to list of tokens"68"
# added choice "68"
# added choice "20"
# added source code postfix token to list of tokens"11"
# added choice "101"
# added choice "88"
# checking project "total_c-ares"
# checking project "total_exiv2"
# added choice "74"
# added source code postfix token to list of tokens"109"
# added source code postfix token to list of tokens"17"
# added source code postfix token to list of tokens"27"
# added source code postfix token to list of tokens"25"
# added choice "95"
# added choice "75"
# added source code postfix token to list of tokens"106"
# added choice "24"
# added source code postfix token to list of tokens"41"
# added choice "106"
# added source code postfix token to list of tokens"67"
# added source code prefix token to list of tokens"44"
# added source code postfix token to list of tokens"73"
# added choice "84"
# added choice "49"
# added choice "44"
# added choice "31"
# checking project "total_freetype2"
# added source code postfix token to list of tokens"113"
# checking project "total_grok"
# added choice "22"
# added source code postfix token to list of tokens"89"
# added source code postfix token to list of tokens"128"
# added choice "128"
# added choice "91"
# checking project "total_guetzli"
# checking project "total_harfbuzz"
# added choice "7"
# checking project "total_lcms"
# checking project "total_libarchive"
# added source code postfix token to list of tokens"136"
# added choice "136"
# checking project "total_libexif"
# checking project "total_libhtp"
# checking project "total_libpng"
# checking project "total_libsndfile"
# added choice "4"
# checking project "total_libssh"
# added choice "30"
# added choice "85"
# added choice "72"
# checking project "total_libxml2"
# added source code postfix token to list of tokens"153"
# added choice "153"
# checking project "total_ndpi"
# checking project "total_openthread"
# checking project "total_pcre2"
# checking project "total_proj4"
# checking project "total_re2"
# added source code postfix token to list of tokens"9"
# added choice "14"
# checking project "total_sqlite3"
# checking project "total_usrsctp"
# checking project "total_vorbis"
# checking project "total_woff2"
# checking project "total_wpantund"
# checking project "total_yara"
# checking project "total_zstd"
# writing to "../record/project_data"
# writing to "../record/token_choices"
# writing to "../record/source_code_tokens"
# writing to "../record/max_len"
# writing to "../record/label_len"
