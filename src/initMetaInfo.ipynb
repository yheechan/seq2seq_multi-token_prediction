# %%
import recorder

# %%
proj_list = [
    'boringssl', 'c-ares',
    'freetype2', 'guetzli',
    'harfbuzz', 'lcms',
    'libpng', 'libssh',
    'libxml2', 'pcre2',
    'proj4', 're2',
    'sqlite3', 'vorbis',
    'woff2', 'wpantund'
]

# %%
recorder.recordInfo(proj_list)
# Out:
# checking project "boringssl"
# added choice "33"
# added source code token "0"
# added source code token "128"
# added source code token "119"
# added source code token "2"
# added source code token "47"
# added source code token "134"
# added source code token "48"
# added source code token "49"
# added source code token "124"
# added source code token "56"
# added source code token "106"
# added source code token "91"
# added source code token "50"
# added source code token "88"
# added source code token "33"
# added choice "2"
# added source code token "117"
# added source code token "111"
# added source code token "133"
# added source code token "45"
# added source code token "46"
# added source code token "87"
# added source code token "86"
# added source code token "54"
# added source code token "212"
# added source code token "84"
# added source code token "90"
# added source code token "105"
# added source code token "62"
# added source code token "89"
# ...
