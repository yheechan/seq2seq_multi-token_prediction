# %%
import recorder

# %%
proj_list = [
    'boringssl', 'c-ares',
    'freetype2', 'guetzli',
    'harfbuzz', 'lcms',
    'libarchive', 'libpng',
    'libssh', 'libxml2',
    'pcre2', 'proj4',
    're2', 'sqlite3',
    'vorbis', 'woff2',
    'wpantund'
]

# %%
recorder.recordInfo(proj_list)
# Out:
# checking project "boringssl"
# added choice "33"
# added source code prefix token to list of tokens"0"
# added source code prefix token to list of tokens"128"
# added source code prefix token to list of tokens"119"
# added source code prefix token to list of tokens"2"
# added source code prefix token to list of tokens"47"
# added source code prefix token to list of tokens"134"
# added source code prefix token to list of tokens"48"
# added source code prefix token to list of tokens"49"
# added source code prefix token to list of tokens"124"
# added source code postfix token to list of tokens"56"
# added source code postfix token to list of tokens"106"
# added source code postfix token to list of tokens"91"
# added source code postfix token to list of tokens"50"
# added source code postfix token to list of tokens"88"
# added choice "2"
# added source code prefix token to list of tokens"33"
# added source code postfix token to list of tokens"117"
# ...
